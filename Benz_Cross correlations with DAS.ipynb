# %% [markdown]
# # NoisePy4DAS: SeaDAS-N as an example
#
# - Yiyu Ni (niyiyu@uw.edu)
# - Department of Earth and Space Sciences, University of Washington
#
# - Project URL:
#     - https://github.com/niyiyu/DASstore
#     - https://github.com/chengxinjiang/NoisePy_4DAS
#     - https://github.com/niyiyu/NoisePy4DAS-SeaDAS
#
# - SCEC Cyber Training for Seismology (May 9 - 12, 2023)
#     - https://seisscoped.org/HPS/
#
# - More about SeaDAS-N experiment at Photonic Sensing Facility (PSF)
#   - https://psf.uw.edu (Lead PI: Brad Lipovsky)
#
# - Last updated: May 8, 2023
#
# #### SeaDAS-N
# (a) Map showing the location of the SeaDAS-N cable (solid line) connecting Seattle and Bothell campus of the University of Washington in Seattle, Washington, United States. Only the red segment was used during December 2022 for data collection. (b) One-hour SeaDAS-N raw data (in radians) of all 2089 channels. The Sintela Onyx interrogator unit samples at 100 Hz, with 4.78-meter channel spacing and 9.56-meter gauge length. The example plot starts 2022-12-15 13:30:00 UTC. The gray region indicates a one-minute data gap. The clipped sub-array (channel $\sim$1100-1700) is from the segment where the cable is above the ground.

# %% [markdown]
# ![title](https://github.com/niyiyu/NoisePy4DAS-SeaDAS/blob/main/figures/seadas_december_overview.png?raw=true)

# %% [markdown]
# # Only run one based on your environment
# **If you run this tutorial on google colab, install required packages using the code cell below**
#
# ⚠️ You would need to restart the run time to make ObsPy running properly.

# %%
# may take ~1 minute to install
# !pip install obspy scipy h5py numpy tiledb==0.19.0 s3fs fsspec matplotlib zarr tqdm pyasdf
# !git clone https://github.com/niyiyu/NoisePy4DAS-SeaDAS
# Out:
# Collecting obspy
#   Downloading obspy-1.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 48.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Collecting tiledb==0.19.0
#   Downloading tiledb-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.7/20.7 MB 14.9 MB/s eta 0:00:00
# Collecting s3fs
#   Downloading s3fs-2024.3.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (2023.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Collecting zarr
#   Downloading zarr-2.17.2-py3-none-any.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.2)
# Collecting pyasdf
#   Downloading pyasdf-0.8.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tiledb==0.19.0) (24.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from obspy) (4.9.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from obspy) (67.7.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from obspy) (2.0.29)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from obspy) (4.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from obspy) (2.31.0)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs)
#   Downloading aiobotocore-2.12.3-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.7 MB/s eta 0:00:00
# Collecting fsspec
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from s3fs) (3.9.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Collecting asciitree (from zarr)
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numcodecs>=0.10.0 (from zarr)
#   Downloading numcodecs-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 28.2 MB/s eta 0:00:00
# Collecting fasteners (from zarr)
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Collecting colorama (from pyasdf)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting dill (from pyasdf)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.8 MB/s eta 0:00:00
# Collecting prov (from pyasdf)
#   Downloading prov-2.0.0-py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 24.4 MB/s eta 0:00:00
# Collecting botocore<1.34.70,>=1.34.41 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading botocore-1.34.69-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.10/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.14.1)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from prov->pyasdf) (3.3)
# Collecting rdflib>=4.2.1 (from prov->pyasdf)
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->obspy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->obspy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->obspy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->obspy) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->obspy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->obspy) (3.0.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=4.2.1->prov->pyasdf)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.5 MB/s eta 0:00:00
# Building wheels for collected packages: asciitree
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5034 sha256=0e1e0cd534558144b410af6ff67179ac4f4823346292bbac84a4b3c2e900ed36
#   Stored in directory: /root/.cache/pip/wheels/7f/4e/be/1171b40f43b918087657ec57cf3b81fa1a2e027d8755baa184
# Successfully built asciitree
# Installing collected packages: asciitree, tiledb, numcodecs, jmespath, isodate, fsspec, fasteners, dill, colorama, aioitertools, zarr, rdflib, botocore, prov, obspy, aiobotocore, s3fs, pyasdf
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.2.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-nccl-cu12==2.19.3; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.3.1 which is incompatible.
# Successfully installed aiobotocore-2.12.3 aioitertools-0.11.0 asciitree-0.3.3 botocore-1.34.69 colorama-0.4.6 dill-0.3.8 fasteners-0.19 fsspec-2024.3.1 isodate-0.6.1 jmespath-1.0.1 numcodecs-0.12.1 obspy-1.4.0 prov-2.0.0 pyasdf-0.8.1 rdflib-7.0.0 s3fs-2024.3.1 tiledb-0.19.0 zarr-2.17.2
# Cloning into 'NoisePy4DAS-SeaDAS'...
# remote: Enumerating objects: 303, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 303 (delta 24), reused 34 (delta 14), pack-reused 256
# Receiving objects: 100% (303/303), 38.04 MiB | 34.53 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# on colab
import sys
sys.path.append("./NoisePy4DAS-SeaDAS/src")
sys.path.append("./NoisePy4DAS-SeaDAS/DASstore")

# %% [markdown]
# **If you run the tutorial through docker, or if you clone the repo, run the cell below**

# %%
# on Docker/local
import sys
sys.path.append("../src")
sys.path.append("../DASstore")

# %% [markdown]
# ## 0 import necessary packages

# %%
import os
import time
from datetime import datetime, timedelta

import h5py
import numpy as np
import DAS_module
import matplotlib.pyplot as plt
from tqdm import tqdm

from dasstore.zarr import Client

# %% [markdown]
# ## 1 connect to the DAS data client

# %% [markdown]
# We store the DAS data in the Zarr format on an object storage machine at University of Washington (endpoint [`http://dasway.ess.washington.edu`](http://dasway.ess.washington.edu/)). The data can be downloaded through a `DASstore.zarr.Client`. Another copy of this data is available on AWS S3 (`s3://seadas-december-2022` in `us-west-2` region). Both copies allow public access during the workshop so that you can download the data without any access key.
#
# ⚠️If you see `ACCESS DENY` error in the following block, it may due to a temporarily access policy change. You could try later if during the workshop, or reach out to the team if after the workshop (if you are interested in using the SeaDAS data).

# %%
# client arguments for DASway.ess.washington.edu
# (server in UW ESS)
bucket = "seadas-december-2022"
endpoint = "dasway.ess.washington.edu"
secure = True   # HTTPs

# prepare client
client = Client(bucket, endpoint, secure = secure, anon = True)
client
# Out:
# Endpoint:  	 https://dasway.ess.washington.edu
# Path:    	 s3://seadas-december-2022
# Anonymous: 	 True
# Backend:   	 Zarr

# %% [markdown]
# ⚠️**egress cost applied**

# %%
# # client arguments for AWS S3
# # (AWS S3 server)
# bucket = "seadas-december-2022"
# endpoint = "s3.us-west-2.amazonaws.com"
# secure = True   # HTTPs

# # prepare client
# client = Client(bucket, endpoint, secure = secure, anon = True)
# client

# %% [markdown]
# ### metadata
# show acquisiton start and end time

# %%
print(f"acquisition starts at {client.meta['acquisition.acquisition_start_time']}")
print(f"acquisition ends at {client.meta['acquisition.acquisition_end_time']}")
# Out:
# acquisition starts at 2022-12-01T00:00:00.000000
# acquisition ends at 2022-12-31T23:59:59.990000

# %% [markdown]
# `client.get_metadata()` function provides more information about this DAS data. we focus on the convention proposed by the DAS Research Coordination Network (RCN, https://www.iris.edu/hq/initiatives/das_rcn), which was a NSF-supported community effort to define common metadata for DAS. As of May 2023, the DAS-RCN defined five levels of metadata describing an experiment under this convention: Overview, Cable, Fiber, Interrogator, and Acquisition. These metadata are saved with the raw data supported by Zarr and TileDB formats as key-value-pair attributes. Additional, channel-specific information (channel number, location, and uncertainty) is proposed by the DAS-RCN to be saved in a separate comma-separated values (CSV) file, which is yet included here.

# %%
metadata = client.get_metadata()
client.get_metadata()
# Out:
# {'_ARRAY_DIMENSIONS': ['channel', 'time'],
#  'acquisition.acquisition_end_time': '2022-12-31T23:59:59.990000',
#  'acquisition.acquisition_id': 'N/A',
#  'acquisition.acquisition_sample_rate': 100,
#  'acquisition.acquisition_start_time': '2022-12-01T00:00:00.000000',
#  'acquisition.archived_sample_rate': 'N/A',
#  'acquisition.channel_spacing': '4.78 [m]',
#  'acquisition.comment': 'N/A',
#  'acquisition.decimation': 'N/A',
#  'acquisition.filtering': 'N/A',
#  'acquisition.gauge_length': '9.56 [m]',
#  'acquisition.interrogator_rate': 'N/A',
#  'acquisition.number_of_channels': '2089',
#  'acquisition.pulse_repetition_rate': 'N/A',
#  'acquisition.pulse_width': 'N/A',
#  'acquisition.unit_of_measure': 'N/A',
#  'cable_and_fiber.attenuation': 'N/A',
#  'cable_and_fiber.cable_characteristics': 'N/A',
#  'cable_and_fiber.cable_connector_coordinates': 'N/A',
#  'cable_and_fiber.cable_coordinates': 'N/A',
#  'cable_and_fiber.cable_diameter': 'N/A',
#  'cable_and_fiber.cable_end_time': 'N/A',
#  'cable_and_fiber.cable_environment': 'N/A',
#  'cable_and_fiber.cable_fiber_id': 'N/A',
#  'cable_and_fiber.cable_model': 'N/A',
#  'cable_and_fiber.cable_start_time': 'N/A',
#  'cable_and_fiber.comment': 'N/A',
#  'cable_and_fiber.fiber_end_location': 'N/A',
#  'cable_and_fiber.fiber_geometry': 'N/A',
#  'cable_and_fiber.fiber_length': 'N/A',
#  'cable_and_fiber.fiber_mode': 'continuous',
#  'cable_and_fiber.fiber_refraction_index': 'N/A',
#  'cable_and_fiber.fiber_start_location': 'N/A',
#  'cable_and_fiber.winding_angle': 'N/A',
#  'interrogator.comment': 'N/A',
#  'interrogator.interrogator_id': 'N/A',
#  'interrogator.manufacturer': 'N/A',
#  'interrogator.model': 'N/A',
#  'interrogator.unit_of_measure': '[radian]',
#  'overview.collection_mode': 'continuous',
#  'overview.comment': 'N/A',
#  'overview.deployment_type': 'temporary',
#  'overview.end_datetime': '2022-12-31',
#  'overview.location': 'Seattle, WA',
#  'overview.network': 'N/A',
#  'overview.number_of_interrogators': 1,
#  'overview.principle_investigators': 'University of Washington',
#  'overview.purpose_of_collection': 'experiment',
#  'overview.site_name': 'SeaDAS North',
#  'overview.start_datetime': '2022-12-01'}

# %%
cha_spacing = float(metadata['acquisition.channel_spacing'].split(' ')[0])
gauge_length = float(metadata['acquisition.gauge_length'].split(' ')[0])
nchas = int(metadata['acquisition.number_of_channels'].split(' ')[0])
print(f"number of channels: {nchas}")
print(f"channel spacing: {cha_spacing} meter")
print(f"guage length: {gauge_length} meter")
# Out:
# number of channels: 2089
# channel spacing: 4.78 meter
# guage length: 9.56 meter

# %% [markdown]
# ## 2 download data
#
# For SeaDAS-N data with 2089 channels sampled at 100 Hz, one minute of data is ~40 MB in raw HDF5 format. Ten minute ~400 MB. One hour is about ~2.4 GB.

# %% [markdown]
# ### DASstore `client.get_data` function
# DAS data is, by nature, a 2D array with a time dimension (as the sampling rate of the interrogator) and a channel dimension (effectively space). So when requesting the DAS data, one would need to specify the channel range and the time range. Thus, **three paramemeters are required for the get_data function**.
# - `channels`: channel index as numpy array, or list
# - `starttime`: start time in string format (UTC)
# - `endtime`: end time in string format (UTC)

# %%
t0 = time.time()
cha1, cha2 = 500, 1000
alldata = client.get_data(channels = np.arange(cha1, cha2),
                          starttime = "2022-12-15T13:30:00.000",
                          endtime   = "2022-12-15T13:31:00.000")
print(f"data is of shape {alldata.shape}")
t1 = time.time()
print(f"it takes %.3f seconds to download data" % (t1 - t0))
# Out:
# data is of shape (500, 6000)
# it takes 1.441 seconds to download data

# %% [markdown]
# Also note that the data is loaded directly into RAM so that no local storage is needed.

# %%
plt.figure(figsize = (10, 6), dpi = 100)
plt.imshow(alldata, aspect = 'auto', extent = [0, 6000, cha1, cha2],
           cmap = 'RdBu', vmax = 1.5, vmin = -1.5, origin='lower')
plt.ylabel("Channel number", fontsize = 15)
plt.xlabel("Time", fontsize = 20)
plt.ylim([0, 2089])
twiny = plt.gca().twinx()
twiny.set_yticks(np.linspace(0, 2000, 9),
                [int(i* cha_spacing) for i in np.linspace(0, 2000, 9)])
twiny.set_ylabel("Distance along cable (m)", fontsize = 15)
plt.colorbar(pad = 0.15)

# %% [markdown]
# ## 3 cross-correlate with NoisePy4DAS
# ### 3.1 parameters

# %%
sps       = 100                 # current sampling rate
samp_freq = 50                  # targeted sampling rate
freqmin   = 1                   # pre filtering frequency bandwidth
freqmax   = 49.9                  # note this cannot exceed Nquist freq

freq_norm   = 'no'             # 'no' for no whitening, or 'rma' for running-mean average, 'phase_only' for sign-bit normalization in freq domain.
time_norm   = 'no'         # 'no' for no normalization, or 'rma', 'one_bit' for normalization in time domain
cc_method   = 'xcorr'           # 'xcorr' for pure cross correlation, 'deconv' for deconvolution; FOR "COHERENCY" PLEASE set freq_norm to "rma", time_norm to "no" and cc_method to "xcorr"
smooth_N    = 100               # moving window length for time domain normalization if selected (points)
smoothspect_N  = 100            # moving window length to smooth spectrum amplitude (points)
maxlag      = 8                 # lags of cross-correlation to save (sec)

# criteria for data selection
max_over_std = 10               # threahold to remove window of bad signals: set it to 10*9 if prefer not to remove them

cc_len = 60                     # correlate length in second
step   = 60                     # stepping length in second

# start and end channel index for the sub-array
cha1, cha2 = 500, 1000

cha_list = np.array(range(cha1, cha2))
nsta = len(cha_list)
n_pair = int((nsta+1)*nsta/2)
n_lag = maxlag * samp_freq * 2 + 1

prepro_para = {'freqmin':freqmin,
               'freqmax':freqmax,
               'sps':sps,
               'npts_chunk':cc_len*sps,
               'nsta':nsta,
               'cha_list':cha_list,
               'samp_freq':samp_freq,
               'freq_norm':freq_norm,
               'time_norm':time_norm,
               'cc_method':cc_method,
               'smooth_N':smooth_N,
               'smoothspect_N':smoothspect_N,
               'maxlag':maxlag,
               'max_over_std':max_over_std}

# # you can save this parameter file to local
# metadata = os.path.join(CCFDIR, 'prepro_fft_info.txt')
# # output parameter info
# fout = open(metadata,'w')
# fout.write(str(prepro_para));fout.close()

# %% [markdown]
# ### 3.2 get data

# %%
# get data
minute_data = client.get_data(cha_list,
                       starttime = "2022-12-01T00:00:00",
                       endtime = "2022-12-01T00:01:00")
print(f"one minute of sub-array data is of shape {minute_data.shape}")
# Out:
# one minute of sub-array data is of shape (500, 6000)

# %%
plt.figure(figsize = (10, 5), dpi = 100)
plt.imshow(minute_data, aspect = 'auto',
           cmap = 'RdBu', vmax = 1.5, vmin = -1.5, origin='lower')
_ =plt.yticks(np.linspace(cha1, cha2, 4) - cha1,
              [int(i) for i in np.linspace(cha1, cha2, 4)], fontsize = 12)
plt.ylabel("Channel number", fontsize = 15)
plt.xlabel("Time", fontsize = 15)
twiny = plt.gca().twinx()
twiny.set_yticks(np.linspace(0, cha2 - cha1, 4),
                             [int(i* cha_spacing) for i in np.linspace(cha1, cha2, 4)])
twiny.set_ylabel("Distance along cable (m)", fontsize = 15)
plt.colorbar(pad = 0.1)

# %% [markdown]
# ### 3.3 pre-processing

# %%
trace_stdS, dataS = DAS_module.preprocess_raw_make_stat(minute_data.T, prepro_para)

plt.figure(figsize = (10, 5), dpi = 100)
plt.imshow(dataS, aspect = 'auto',
           cmap = 'RdBu', vmax = 1.5, vmin = -1.5, origin='lower')
_ =plt.yticks(np.linspace(cha1, cha2, 4) - cha1,
              [int(i) for i in np.linspace(cha1, cha2, 4)], fontsize = 12)
plt.ylabel("Channel number", fontsize = 15)
plt.xlabel("Time", fontsize = 15)
twiny = plt.gca().twinx()
twiny.set_yticks(np.linspace(0, cha2 - cha1, 4),
                             [int(i* cha_spacing) for i in np.linspace(cha1, cha2, 4)])
twiny.set_ylabel("Distance along cable (m)", fontsize = 15)
plt.colorbar(pad = 0.1)

# %% [markdown]
# ### 3.4 FFT, temporal and frequency normalizaiton (if specified)

# %%
white_spect = DAS_module.noise_processing(dataS, prepro_para)
Nfft = white_spect.shape[1]; Nfft2 = Nfft // 2
data = white_spect[:, :Nfft2]
# del dataS, white_spect

print(data.shape, data.dtype)
# Out:
# (500, 1500) complex64

# %% [markdown]
# ### 3.5 channel-pair selection

# %%
ind = np.where((trace_stdS < prepro_para['max_over_std']) &
                        (trace_stdS > 0) &
                (np.isnan(trace_stdS) == 0))[0]
if not len(ind):
    raise ValueError('the max_over_std criteria is too high which results in no data')
sta = cha_list[ind]
white_spect = data[ind]

print(white_spect.shape, white_spect.dtype)
# Out:
# (432, 1500) complex64

# %% [markdown]
# ### 3.6 cross-correlate over all channel pairs

# %%
# loop over all stations
for iiS in range(len(sta)):
    # smooth the source spectrum
    sfft1 = DAS_module.smooth_source_spect(white_spect[iiS], prepro_para)

    # correlate one source with all receivers
    corr, tindx = DAS_module.correlate(sfft1, white_spect[iiS:], prepro_para, Nfft)

    print(f"source channel index: {sta[iiS]}, correlation shape: {corr.shape}")
# Out:
# source channel index: 500, correlation shape: (428, 801)
# source channel index: 501, correlation shape: (427, 801)
# source channel index: 502, correlation shape: (426, 801)
# source channel index: 503, correlation shape: (425, 801)
# source channel index: 504, correlation shape: (424, 801)
# source channel index: 505, correlation shape: (423, 801)
# source channel index: 506, correlation shape: (422, 801)
# source channel index: 507, correlation shape: (421, 801)
# source channel index: 508, correlation shape: (420, 801)
# source channel index: 509, correlation shape: (419, 801)
# source channel index: 510, correlation shape: (418, 801)
# source channel index: 511, correlation shape: (417, 801)
# source channel index: 512, correlation shape: (416, 801)
# source channel index: 513, correlation shape: (415, 801)
# source channel index: 514, correlation shape: (414, 801)
# source channel index: 515, correlation shape: (413, 801)
# source channel index: 516, correlation shape: (412, 801)
# source channel index: 517, correlation shape: (411, 801)
# source channel index: 518, correlation shape: (410, 801)
# source channel index: 519, correlation shape: (409, 801)
# source channel index: 520, correlation shape: (409, 801)
# source channel index: 521, correlation shape: (408, 801)
# source channel index: 522, correlation shape: (407, 801)
# source channel index: 523, correlation shape: (406, 801)
# source channel index: 524, correlation shape: (405, 801)
# source channel index: 525, correlation shape: (404, 801)
# source channel index: 526, correlation shape: (402, 801)
# source channel index: 527, correlation shape: (401, 801)
# source channel index: 528, correlation shape: (401, 801)
# source channel index: 529, correlation shape: (399, 801)
# source channel index: 530, correlation shape: (398, 801)
# source channel index: 531, correlation shape: (397, 801)
# source channel index: 532, correlation shape: (396, 801)
# source channel index: 533, correlation shape: (395, 801)
# source channel index: 534, correlation shape: (395, 801)
# source channel index: 535, correlation shape: (394, 801)
# source channel index: 536, correlation shape: (392, 801)
# source channel index: 537, correlation shape: (391, 801)
# source channel index: 538, correlation shape: (390, 801)
# source channel index: 539, correlation shape: (389, 801)
# source channel index: 540, correlation shape: (388, 801)
# source channel index: 541, correlation shape: (388, 801)
# source channel index: 542, correlation shape: (386, 801)
# source channel index: 543, correlation shape: (385, 801)
# source channel index: 544, correlation shape: (384, 801)
# source channel index: 545, correlation shape: (383, 801)
# source channel index: 546, correlation shape: (381, 801)
# source channel index: 547, correlation shape: (382, 801)
# source channel index: 548, correlation shape: (381, 801)
# source channel index: 549, correlation shape: (380, 801)
# source channel index: 550, correlation shape: (379, 801)
# source channel index: 551, correlation shape: (378, 801)
# source channel index: 552, correlation shape: (377, 801)
# source channel index: 553, correlation shape: (378, 801)
# source channel index: 554, correlation shape: (377, 801)
# source channel index: 555, correlation shape: (376, 801)
# source channel index: 556, correlation shape: (375, 801)
# source channel index: 557, correlation shape: (374, 801)
# source channel index: 558, correlation shape: (372, 801)
# source channel index: 559, correlation shape: (371, 801)
# source channel index: 560, correlation shape: (370, 801)
# source channel index: 561, correlation shape: (369, 801)
# source channel index: 562, correlation shape: (368, 801)
# source channel index: 563, correlation shape: (367, 801)
# source channel index: 564, correlation shape: (367, 801)
# source channel index: 565, correlation shape: (366, 801)
# source channel index: 566, correlation shape: (363, 801)
# source channel index: 567, correlation shape: (362, 801)
# source channel index: 568, correlation shape: (361, 801)
# source channel index: 569, correlation shape: (361, 801)
# source channel index: 570, correlation shape: (359, 801)
# source channel index: 571, correlation shape: (358, 801)
# source channel index: 572, correlation shape: (358, 801)
# source channel index: 573, correlation shape: (357, 801)
# source channel index: 574, correlation shape: (356, 801)
# source channel index: 575, correlation shape: (354, 801)
# source channel index: 576, correlation shape: (353, 801)
# source channel index: 577, correlation shape: (352, 801)
# source channel index: 582, correlation shape: (351, 801)
# source channel index: 583, correlation shape: (350, 801)
# source channel index: 584, correlation shape: (349, 801)
# source channel index: 585, correlation shape: (348, 801)
# source channel index: 586, correlation shape: (347, 801)
# source channel index: 587, correlation shape: (346, 801)
# source channel index: 588, correlation shape: (344, 801)
# source channel index: 589, correlation shape: (344, 801)
# source channel index: 590, correlation shape: (343, 801)
# source channel index: 591, correlation shape: (342, 801)
# source channel index: 592, correlation shape: (341, 801)
# source channel index: 593, correlation shape: (340, 801)
# source channel index: 594, correlation shape: (340, 801)
# source channel index: 595, correlation shape: (339, 801)
# source channel index: 596, correlation shape: (338, 801)
# source channel index: 597, correlation shape: (338, 801)
# source channel index: 598, correlation shape: (336, 801)
# source channel index: 599, correlation shape: (335, 801)
# source channel index: 600, correlation shape: (335, 801)
# source channel index: 601, correlation shape: (333, 801)
# source channel index: 602, correlation shape: (332, 801)
# source channel index: 603, correlation shape: (331, 801)
# source channel index: 604, correlation shape: (329, 801)
# source channel index: 605, correlation shape: (328, 801)
# source channel index: 606, correlation shape: (327, 801)
# source channel index: 607, correlation shape: (326, 801)
# source channel index: 608, correlation shape: (325, 801)
# source channel index: 609, correlation shape: (324, 801)
# source channel index: 610, correlation shape: (323, 801)
# source channel index: 611, correlation shape: (322, 801)
# source channel index: 612, correlation shape: (322, 801)
# source channel index: 613, correlation shape: (321, 801)
# source channel index: 614, correlation shape: (319, 801)
# source channel index: 615, correlation shape: (318, 801)
# source channel index: 616, correlation shape: (317, 801)
# source channel index: 617, correlation shape: (316, 801)
# source channel index: 618, correlation shape: (315, 801)
# source channel index: 619, correlation shape: (314, 801)
# source channel index: 622, correlation shape: (313, 801)
# source channel index: 625, correlation shape: (312, 801)
# source channel index: 626, correlation shape: (312, 801)
# source channel index: 628, correlation shape: (310, 801)
# source channel index: 630, correlation shape: (310, 801)
# source channel index: 631, correlation shape: (310, 801)
# source channel index: 632, correlation shape: (309, 801)
# source channel index: 633, correlation shape: (308, 801)
# source channel index: 634, correlation shape: (307, 801)
# source channel index: 635, correlation shape: (306, 801)
# source channel index: 636, correlation shape: (305, 801)
# source channel index: 637, correlation shape: (304, 801)
# source channel index: 638, correlation shape: (302, 801)
# source channel index: 639, correlation shape: (302, 801)
# source channel index: 640, correlation shape: (301, 801)
# source channel index: 641, correlation shape: (300, 801)
# source channel index: 642, correlation shape: (298, 801)
# source channel index: 643, correlation shape: (298, 801)
# source channel index: 644, correlation shape: (297, 801)
# source channel index: 645, correlation shape: (296, 801)
# source channel index: 646, correlation shape: (295, 801)
# source channel index: 647, correlation shape: (294, 801)
# source channel index: 648, correlation shape: (293, 801)
# source channel index: 649, correlation shape: (292, 801)
# source channel index: 650, correlation shape: (290, 801)
# source channel index: 651, correlation shape: (290, 801)
# source channel index: 652, correlation shape: (288, 801)
# source channel index: 653, correlation shape: (287, 801)
# source channel index: 654, correlation shape: (286, 801)
# source channel index: 655, correlation shape: (285, 801)
# source channel index: 656, correlation shape: (284, 801)
# source channel index: 657, correlation shape: (284, 801)
# source channel index: 658, correlation shape: (283, 801)
# source channel index: 659, correlation shape: (282, 801)
# source channel index: 660, correlation shape: (281, 801)
# source channel index: 661, correlation shape: (280, 801)
# source channel index: 662, correlation shape: (278, 801)
# source channel index: 663, correlation shape: (278, 801)
# source channel index: 664, correlation shape: (277, 801)
# source channel index: 665, correlation shape: (275, 801)
# source channel index: 668, correlation shape: (274, 801)
# source channel index: 669, correlation shape: (274, 801)
# source channel index: 670, correlation shape: (273, 801)
# source channel index: 671, correlation shape: (271, 801)
# source channel index: 672, correlation shape: (271, 801)
# source channel index: 673, correlation shape: (270, 801)
# source channel index: 674, correlation shape: (269, 801)
# source channel index: 675, correlation shape: (268, 801)
# source channel index: 676, correlation shape: (267, 801)
# source channel index: 677, correlation shape: (265, 801)
# source channel index: 678, correlation shape: (264, 801)
# source channel index: 679, correlation shape: (264, 801)
# source channel index: 680, correlation shape: (262, 801)
# source channel index: 681, correlation shape: (261, 801)
# source channel index: 682, correlation shape: (261, 801)
# source channel index: 683, correlation shape: (260, 801)
# source channel index: 684, correlation shape: (259, 801)
# source channel index: 685, correlation shape: (258, 801)
# source channel index: 686, correlation shape: (257, 801)
# source channel index: 687, correlation shape: (255, 801)
# source channel index: 688, correlation shape: (254, 801)
# source channel index: 689, correlation shape: (255, 801)
# source channel index: 690, correlation shape: (254, 801)
# source channel index: 691, correlation shape: (253, 801)
# source channel index: 692, correlation shape: (252, 801)
# source channel index: 693, correlation shape: (251, 801)
# source channel index: 694, correlation shape: (249, 801)
# source channel index: 695, correlation shape: (248, 801)
# source channel index: 696, correlation shape: (247, 801)
# source channel index: 699, correlation shape: (246, 801)
# source channel index: 700, correlation shape: (246, 801)
# source channel index: 701, correlation shape: (245, 801)
# source channel index: 702, correlation shape: (244, 801)
# source channel index: 703, correlation shape: (243, 801)
# source channel index: 704, correlation shape: (242, 801)
# source channel index: 705, correlation shape: (241, 801)
# source channel index: 706, correlation shape: (240, 801)
# source channel index: 707, correlation shape: (238, 801)
# source channel index: 708, correlation shape: (238, 801)
# source channel index: 709, correlation shape: (236, 801)
# source channel index: 710, correlation shape: (236, 801)
# source channel index: 711, correlation shape: (235, 801)
# source channel index: 712, correlation shape: (233, 801)
# source channel index: 713, correlation shape: (233, 801)
# source channel index: 714, correlation shape: (232, 801)
# source channel index: 715, correlation shape: (231, 801)
# source channel index: 716, correlation shape: (230, 801)
# source channel index: 717, correlation shape: (229, 801)
# source channel index: 718, correlation shape: (228, 801)
# source channel index: 719, correlation shape: (227, 801)
# source channel index: 720, correlation shape: (226, 801)
# source channel index: 721, correlation shape: (225, 801)
# source channel index: 722, correlation shape: (224, 801)
# source channel index: 723, correlation shape: (223, 801)
# source channel index: 724, correlation shape: (222, 801)
# source channel index: 725, correlation shape: (221, 801)
# source channel index: 726, correlation shape: (220, 801)
# source channel index: 727, correlation shape: (219, 801)
# source channel index: 728, correlation shape: (218, 801)
# source channel index: 729, correlation shape: (217, 801)
# source channel index: 730, correlation shape: (216, 801)
# source channel index: 731, correlation shape: (215, 801)
# source channel index: 732, correlation shape: (214, 801)
# source channel index: 734, correlation shape: (212, 801)
# source channel index: 737, correlation shape: (212, 801)
# source channel index: 738, correlation shape: (211, 801)
# source channel index: 739, correlation shape: (210, 801)
# source channel index: 740, correlation shape: (209, 801)
# source channel index: 741, correlation shape: (208, 801)
# source channel index: 742, correlation shape: (207, 801)
# source channel index: 743, correlation shape: (206, 801)
# source channel index: 744, correlation shape: (205, 801)
# source channel index: 745, correlation shape: (204, 801)
# source channel index: 746, correlation shape: (203, 801)
# source channel index: 747, correlation shape: (202, 801)
# source channel index: 748, correlation shape: (201, 801)
# source channel index: 749, correlation shape: (200, 801)
# source channel index: 750, correlation shape: (199, 801)
# source channel index: 751, correlation shape: (198, 801)
# source channel index: 752, correlation shape: (197, 801)
# source channel index: 753, correlation shape: (196, 801)
# source channel index: 754, correlation shape: (195, 801)
# source channel index: 755, correlation shape: (194, 801)
# source channel index: 756, correlation shape: (193, 801)
# source channel index: 757, correlation shape: (192, 801)
# source channel index: 758, correlation shape: (191, 801)
# source channel index: 759, correlation shape: (190, 801)
# source channel index: 760, correlation shape: (189, 801)
# source channel index: 761, correlation shape: (188, 801)
# source channel index: 762, correlation shape: (187, 801)
# source channel index: 764, correlation shape: (186, 801)
# source channel index: 765, correlation shape: (185, 801)
# source channel index: 766, correlation shape: (184, 801)
# source channel index: 767, correlation shape: (183, 801)
# source channel index: 769, correlation shape: (182, 801)
# source channel index: 770, correlation shape: (181, 801)
# source channel index: 771, correlation shape: (180, 801)
# source channel index: 772, correlation shape: (179, 801)
# source channel index: 774, correlation shape: (178, 801)
# source channel index: 776, correlation shape: (177, 801)
# source channel index: 777, correlation shape: (176, 801)
# source channel index: 778, correlation shape: (175, 801)
# source channel index: 780, correlation shape: (174, 801)
# source channel index: 781, correlation shape: (173, 801)
# source channel index: 782, correlation shape: (172, 801)
# source channel index: 783, correlation shape: (171, 801)
# source channel index: 784, correlation shape: (170, 801)
# source channel index: 786, correlation shape: (169, 801)
# source channel index: 790, correlation shape: (168, 801)
# source channel index: 792, correlation shape: (167, 801)
# source channel index: 797, correlation shape: (166, 801)
# source channel index: 798, correlation shape: (165, 801)
# source channel index: 799, correlation shape: (164, 801)
# source channel index: 800, correlation shape: (163, 801)
# source channel index: 801, correlation shape: (162, 801)
# source channel index: 802, correlation shape: (161, 801)
# source channel index: 803, correlation shape: (160, 801)
# source channel index: 804, correlation shape: (159, 801)
# source channel index: 805, correlation shape: (158, 801)
# source channel index: 806, correlation shape: (157, 801)
# source channel index: 807, correlation shape: (156, 801)
# source channel index: 808, correlation shape: (155, 801)
# source channel index: 809, correlation shape: (154, 801)
# source channel index: 810, correlation shape: (153, 801)
# source channel index: 811, correlation shape: (152, 801)
# source channel index: 812, correlation shape: (151, 801)
# source channel index: 813, correlation shape: (150, 801)
# source channel index: 814, correlation shape: (149, 801)
# source channel index: 815, correlation shape: (148, 801)
# source channel index: 816, correlation shape: (147, 801)
# source channel index: 817, correlation shape: (146, 801)
# source channel index: 818, correlation shape: (145, 801)
# source channel index: 819, correlation shape: (144, 801)
# source channel index: 820, correlation shape: (143, 801)
# source channel index: 821, correlation shape: (142, 801)
# source channel index: 827, correlation shape: (141, 801)
# source channel index: 828, correlation shape: (140, 801)
# source channel index: 829, correlation shape: (139, 801)
# source channel index: 830, correlation shape: (138, 801)
# source channel index: 831, correlation shape: (137, 801)
# source channel index: 832, correlation shape: (136, 801)
# source channel index: 833, correlation shape: (135, 801)
# source channel index: 834, correlation shape: (134, 801)
# source channel index: 835, correlation shape: (133, 801)
# source channel index: 836, correlation shape: (132, 801)
# source channel index: 837, correlation shape: (131, 801)
# source channel index: 838, correlation shape: (130, 801)
# source channel index: 839, correlation shape: (129, 801)
# source channel index: 840, correlation shape: (128, 801)
# source channel index: 841, correlation shape: (127, 801)
# source channel index: 842, correlation shape: (126, 801)
# source channel index: 843, correlation shape: (125, 801)
# source channel index: 844, correlation shape: (124, 801)
# source channel index: 845, correlation shape: (123, 801)
# source channel index: 846, correlation shape: (122, 801)
# source channel index: 847, correlation shape: (121, 801)
# source channel index: 848, correlation shape: (120, 801)
# source channel index: 851, correlation shape: (119, 801)
# source channel index: 852, correlation shape: (118, 801)
# source channel index: 853, correlation shape: (117, 801)
# source channel index: 854, correlation shape: (116, 801)
# source channel index: 855, correlation shape: (115, 801)
# source channel index: 856, correlation shape: (114, 801)
# source channel index: 857, correlation shape: (113, 801)
# source channel index: 858, correlation shape: (112, 801)
# source channel index: 859, correlation shape: (111, 801)
# source channel index: 860, correlation shape: (110, 801)
# source channel index: 861, correlation shape: (109, 801)
# source channel index: 862, correlation shape: (108, 801)
# source channel index: 863, correlation shape: (107, 801)
# source channel index: 864, correlation shape: (106, 801)
# source channel index: 865, correlation shape: (105, 801)
# source channel index: 866, correlation shape: (103, 801)
# source channel index: 867, correlation shape: (102, 801)
# source channel index: 868, correlation shape: (100, 801)
# source channel index: 869, correlation shape: (101, 801)
# source channel index: 870, correlation shape: (100, 801)
# source channel index: 871, correlation shape: (99, 801)
# source channel index: 873, correlation shape: (97, 801)
# source channel index: 874, correlation shape: (96, 801)
# source channel index: 877, correlation shape: (95, 801)
# source channel index: 878, correlation shape: (95, 801)
# source channel index: 883, correlation shape: (94, 801)
# source channel index: 884, correlation shape: (93, 801)
# source channel index: 885, correlation shape: (92, 801)
# source channel index: 886, correlation shape: (91, 801)
# source channel index: 887, correlation shape: (90, 801)
# source channel index: 888, correlation shape: (89, 801)
# source channel index: 889, correlation shape: (88, 801)
# source channel index: 890, correlation shape: (87, 801)
# source channel index: 891, correlation shape: (86, 801)
# source channel index: 892, correlation shape: (85, 801)
# source channel index: 893, correlation shape: (84, 801)
# source channel index: 894, correlation shape: (83, 801)
# source channel index: 895, correlation shape: (82, 801)
# source channel index: 896, correlation shape: (81, 801)
# source channel index: 897, correlation shape: (80, 801)
# source channel index: 898, correlation shape: (79, 801)
# source channel index: 899, correlation shape: (78, 801)
# source channel index: 900, correlation shape: (77, 801)
# source channel index: 901, correlation shape: (76, 801)
# source channel index: 902, correlation shape: (75, 801)
# source channel index: 903, correlation shape: (74, 801)
# source channel index: 904, correlation shape: (73, 801)
# source channel index: 905, correlation shape: (72, 801)
# source channel index: 906, correlation shape: (71, 801)
# source channel index: 907, correlation shape: (70, 801)
# source channel index: 908, correlation shape: (69, 801)
# source channel index: 909, correlation shape: (68, 801)
# source channel index: 910, correlation shape: (67, 801)
# source channel index: 911, correlation shape: (66, 801)
# source channel index: 912, correlation shape: (65, 801)
# source channel index: 913, correlation shape: (64, 801)
# source channel index: 914, correlation shape: (63, 801)
# source channel index: 915, correlation shape: (62, 801)
# source channel index: 916, correlation shape: (61, 801)
# source channel index: 917, correlation shape: (60, 801)
# source channel index: 918, correlation shape: (59, 801)
# source channel index: 919, correlation shape: (58, 801)
# source channel index: 920, correlation shape: (57, 801)
# source channel index: 921, correlation shape: (56, 801)
# source channel index: 922, correlation shape: (55, 801)
# source channel index: 930, correlation shape: (54, 801)
# source channel index: 931, correlation shape: (53, 801)
# source channel index: 932, correlation shape: (52, 801)
# source channel index: 933, correlation shape: (51, 801)
# source channel index: 934, correlation shape: (50, 801)
# source channel index: 935, correlation shape: (49, 801)
# source channel index: 936, correlation shape: (48, 801)
# source channel index: 937, correlation shape: (47, 801)
# source channel index: 938, correlation shape: (46, 801)
# source channel index: 939, correlation shape: (45, 801)
# source channel index: 941, correlation shape: (44, 801)
# source channel index: 946, correlation shape: (43, 801)
# source channel index: 947, correlation shape: (42, 801)
# source channel index: 948, correlation shape: (41, 801)
# source channel index: 949, correlation shape: (40, 801)
# source channel index: 950, correlation shape: (39, 801)
# source channel index: 951, correlation shape: (38, 801)
# source channel index: 952, correlation shape: (37, 801)
# source channel index: 953, correlation shape: (36, 801)
# source channel index: 954, correlation shape: (35, 801)
# source channel index: 955, correlation shape: (34, 801)
# source channel index: 956, correlation shape: (33, 801)
# source channel index: 957, correlation shape: (32, 801)
# source channel index: 958, correlation shape: (31, 801)
# source channel index: 959, correlation shape: (30, 801)
# source channel index: 960, correlation shape: (29, 801)
# source channel index: 961, correlation shape: (28, 801)
# source channel index: 962, correlation shape: (27, 801)
# source channel index: 963, correlation shape: (26, 801)
# source channel index: 964, correlation shape: (25, 801)
# source channel index: 965, correlation shape: (24, 801)
# source channel index: 970, correlation shape: (23, 801)
# source channel index: 971, correlation shape: (22, 801)
# source channel index: 974, correlation shape: (21, 801)
# source channel index: 980, correlation shape: (20, 801)
# source channel index: 981, correlation shape: (19, 801)
# source channel index: 982, correlation shape: (18, 801)
# source channel index: 983, correlation shape: (17, 801)
# source channel index: 984, correlation shape: (16, 801)
# source channel index: 985, correlation shape: (15, 801)
# source channel index: 986, correlation shape: (14, 801)
# source channel index: 987, correlation shape: (13, 801)
# source channel index: 988, correlation shape: (12, 801)
# source channel index: 989, correlation shape: (11, 801)
# source channel index: 990, correlation shape: (10, 801)
# source channel index: 991, correlation shape: (9, 801)
# source channel index: 992, correlation shape: (8, 801)
# source channel index: 993, correlation shape: (7, 801)
# source channel index: 994, correlation shape: (6, 801)
# source channel index: 995, correlation shape: (5, 801)
# source channel index: 996, correlation shape: (4, 801)
# source channel index: 997, correlation shape: (3, 801)
# source channel index: 998, correlation shape: (2, 801)
# source channel index: 999, correlation shape: (1, 801)

# %% [markdown]
# ## 4 10-minute linear stacking
# We create this `corr_full` and `stack_full` matrix to store a sub-stacking results. More specifically, we linearly stack each minute of correlation in memory, and only save the hourly stacking to the CCF storage (local ASDF, S3, etc.)

# %%
corr_full = np.zeros([n_lag, n_pair], dtype = np.float32)
stack_full = np.zeros([1, n_pair], dtype = np.int32)
task_t0 = datetime(year = 2022, month = 12, day = 1,
                   hour = 0, minute = 0, second = 0, microsecond = 0)

n_minute = 10

# %% [markdown]
# We loop over all data chunk. Reminder that the data is on the cloud, and computing is made on this server. So we are downloading the data as we compute at the same time (async option?)

# %%
# each task is one minute
n_minute = 1
pbar = tqdm(range(n_minute))
t_query = 0; t_compute = 0
for imin in pbar:
    t0 = time.time()
    pbar.set_description(f"Processing {task_t0}")
    task_t0 += timedelta(minutes = 1)
    tdata = client.get_data(cha_list,
            starttime = task_t0,
            endtime = task_t0 + timedelta(minutes = 1)).T
    t_query += time.time() - t0

    t1 = time.time()
    # perform pre-processing
    trace_stdS, dataS = DAS_module.preprocess_raw_make_stat(tdata, prepro_para)

    # do normalization if needed
    white_spect = DAS_module.noise_processing(dataS, prepro_para)
    Nfft = white_spect.shape[1]; Nfft2 = Nfft // 2
    data = white_spect[:, :Nfft2]
    del dataS, white_spect

    ind = np.where((trace_stdS < prepro_para['max_over_std']) &
                            (trace_stdS > 0) &
                    (np.isnan(trace_stdS) == 0))[0]
    if not len(ind):
        raise ValueError('the max_over_std criteria is too high which results in no data')
    sta = cha_list[ind]
    white_spect = data[ind]

    # loop over all stations
    for iiS in range(len(sta)):
        # smooth the source spectrum
        sfft1 = DAS_module.smooth_source_spect(white_spect[iiS], prepro_para)

        # correlate one source with all receivers
        corr, tindx = DAS_module.correlate(sfft1, white_spect[iiS:], prepro_para, Nfft)

        # update the receiver list
        tsta = sta[iiS:]
        receiver_lst = tsta[tindx]

        iS = int((cha2*2 - cha1 - sta[iiS] + 1) * (sta[iiS] - cha1) / 2)

        # stacking one minute
        corr_full[:, iS + receiver_lst - sta[iiS]] += corr.T
        stack_full[:, iS + receiver_lst - sta[iiS]] += 1

    t_compute += time.time() - t1
corr_full /= stack_full
print("%.3f seconds in data query, %.3f seconds in xcorr computing" % (t_query, t_compute))
# Out:
# Processing 2022-12-01 00:00:00: 100%|██████████| 1/1 [00:17<00:00, 17.81s/it]
# 1.270 seconds in data query, 16.539 seconds in xcorr computing
# <ipython-input-43-10f2edde3883>:51: RuntimeWarning: invalid value encountered in divide
#   corr_full /= stack_full

# %% [markdown]
# ## 5 visualize and save CCF

# %%
plt.figure(figsize = (12, 5), dpi = 150)

plt.imshow(corr_full[:, :(cha2 - cha1)].T, aspect = 'auto', cmap = 'RdBu',
           vmax = 2e-2, vmin = -2e-2, origin = 'lower', interpolation=None)

_ =plt.yticks(np.linspace(cha1, cha2, 4) - cha1,
              [int(i) for i in np.linspace(cha1, cha2, 4)], fontsize = 12)
_ = plt.xticks(np.arange(0, 801, 200), (np.arange(0, 801, 200) - 400)/50, fontsize = 12)
plt.ylabel("Channel number", fontsize = 16)
plt.xlabel("Time lag (sec)", fontsize = 16)
plt.title("source 500", fontsize = 16)
bar = plt.colorbar(pad = 0.1, format = lambda x, pos: '{:.1f}'.format(x*100))
bar.set_label('Cross-correlation Coefficient ($\\times10^{-2}$)', fontsize = 15)

twiny = plt.gca().twinx()
twiny.set_yticks(np.linspace(0, cha2 - cha1, 4),
                             [int(i* cha_spacing) for i in np.linspace(cha1, cha2, 4)])
twiny.set_ylabel("Distance along cable (m)", fontsize = 15)
# Out:
# Text(0, 0.5, 'Distance along cable (m)')

# %% [markdown]
# ### 5.1 ASDF (Adaptable Seismic Data Format)
# The adaptable seismic data format (ASDF; Krischer et al., 2016) is one of such file formats that uses the HDF5 container to store large time series and metadata. NoisePy takes advantages of ASDF for a structured organization of the cross-correlation data while maintaining the parallel I/O capabilities (Jiang et al., 2020)

# %%
import pyasdf

t0 = time.time()
with pyasdf.ASDFDataSet("./CCF.h5", mpi = False) as ccf_ds:
    for iiS in tqdm(range(len(sta))):
        for iiR in range(nsta - iiS):
            # use the channel number as a way to figure out distance
            Sindx = iiS + cha1
            iS = int((cha2*2 - cha1 - Sindx + 1) * (Sindx - cha1) / 2)
            param = {'sps':samp_freq,
                    'dt': 1/samp_freq,
                    'maxlag':maxlag,
                    'freqmin':freqmin,
                    'freqmax':freqmax}

            # source-receiver pair
            data_type = str(sta[iiS])
            path = f'{Sindx}_{Sindx + iiR}'
            ccf_ds.add_auxiliary_data(data=corr_full[:, iS + iiR],
                                      data_type=data_type,
                                      path=path,
                                      parameters=param)
t1 = time.time()
print(f"it takes %.3f seconds to write this ASDF file" % (t1 - t0))
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_943' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_944' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_945' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_946' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_947' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_948' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_949' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_950' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_951' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_952' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_953' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_954' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_955' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_956' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_957' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_958' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_959' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_960' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_961' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_962' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_963' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_964' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_965' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_966' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_967' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_968' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_969' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_970' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_971' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_972' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_973' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_974' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_975' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_976' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_977' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_978' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_979' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_980' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_981' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_982' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_983' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_984' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_985' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_986' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_987' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_988' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_989' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_990' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_991' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_992' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_993' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_994' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_995' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_996' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_997' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_998' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '963/909_999' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_910' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_911' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_912' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_913' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_914' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_915' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_916' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_917' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_918' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_919' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_920' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_921' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_922' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_923' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_924' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_925' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_926' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_927' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_928' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_929' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_930' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_931' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_932' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_933' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_934' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_935' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_936' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_937' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_938' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_939' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_940' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_941' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_942' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_943' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_944' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_945' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_946' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_947' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_948' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_949' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_950' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_951' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_952' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_953' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_954' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_955' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_956' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_957' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_958' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_959' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_960' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_961' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_962' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_963' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_964' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_965' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_966' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_967' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_968' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_969' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_970' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_971' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_972' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_973' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_974' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_975' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_976' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_977' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_978' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_979' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_980' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_981' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_982' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_983' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_984' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_985' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_986' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_987' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_988' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_989' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_990' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_991' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_992' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_993' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_994' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_995' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_996' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_997' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_998' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '964/910_999' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
#  93%|█████████▎| 411/443 [00:52<00:01, 22.83it/s]/usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_911' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_912' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_913' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_914' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_915' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_916' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_917' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_918' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_919' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_920' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_921' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_922' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_923' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_924' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_925' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_926' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_927' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_928' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_929' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_930' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_931' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_932' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_933' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_934' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_935' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_936' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_937' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_938' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_939' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_940' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_941' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_942' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_943' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_944' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_945' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_946' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_947' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_948' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_949' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_950' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_951' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_952' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_953' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_954' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_955' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_956' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_957' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_958' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_959' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_960' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_961' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_962' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_963' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_964' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_965' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_966' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_967' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_968' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_969' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_970' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_971' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_972' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_973' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_974' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_975' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_976' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_977' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_978' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_979' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_980' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_981' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_982' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_983' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_984' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_985' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_986' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_987' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_988' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_989' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_990' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_991' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_992' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_993' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_994' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_995' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_996' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_997' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_998' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '965/911_999' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_912' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_913' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_914' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_915' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_916' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_917' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_918' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_919' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_920' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_921' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_922' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_923' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_924' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_925' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_926' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_927' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_928' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_929' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_930' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_931' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_932' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_933' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_934' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_935' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_936' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_937' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_938' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_939' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_940' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_941' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_942' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_943' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '966/912_944' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# ...
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_969' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_970' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_971' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_972' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_973' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_974' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_975' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_976' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_977' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_978' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_979' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_980' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_981' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_982' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_983' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_984' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_985' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_986' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_987' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_988' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_989' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_990' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_991' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_992' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_993' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_994' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_995' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_996' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_997' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_998' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '998/941_999' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# 100%|█████████▉| 442/443 [00:54<00:00, 24.57it/s]/usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_942' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_943' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_944' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_945' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_946' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_947' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_948' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_949' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_950' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_951' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_952' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_953' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_954' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_955' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_956' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_957' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_958' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_959' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_960' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_961' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_962' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_963' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_964' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_965' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_966' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_967' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_968' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_969' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_970' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_971' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_972' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_973' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_974' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_975' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_976' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_977' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_978' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_979' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_980' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_981' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_982' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_983' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_984' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_985' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_986' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_987' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_988' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_989' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_990' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_991' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_992' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_993' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_994' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_995' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_996' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_997' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_998' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# /usr/local/lib/python3.10/dist-packages/pyasdf/asdf_data_set.py:722: ASDFWarning: Data '999/942_999' already exists in file. Will not be added!
#   warnings.warn(msg, ASDFWarning)
# 100%|██████████| 443/443 [00:54<00:00,  8.18it/s]
# it takes 54.187 seconds to write this ASDF file

# %% [markdown]
# ### 5.2 TileDB

# %%
import tiledb

t0 = time.time()
dim1 = tiledb.Dim(name="time_lag", domain=(0, n_lag-1), tile=n_lag, dtype=np.uint32,
                  filters = tiledb.FilterList([tiledb.DoubleDeltaFilter(),tiledb.GzipFilter(level=-1)]))
dim2 = tiledb.Dim(name="channel_pair", domain=(0, n_pair-1), tile=100, dtype=np.uint32,
                  filters = tiledb.FilterList([tiledb.DoubleDeltaFilter(),tiledb.GzipFilter(level=-1)]))

rawdata = tiledb.Attr(name="CCF", dtype=np.float32,
                  filters=tiledb.FilterList([tiledb.ByteShuffleFilter(), tiledb.LZ4Filter(level = 5)]),
                     fill=np.nan)

dom = tiledb.Domain(dim1, dim2)
schema = tiledb.ArraySchema(domain=dom, sparse=False, attrs=[rawdata])

tiledb.Array.create(f"./CCF.tdb", schema = schema)

with tiledb.open(f"./CCF.tdb", 'w') as A:
    A[:, :] = corr_full

t1 = time.time()
print(f"it takes %.3f seconds to write this TileDB file" % (t1 - t0))
# Out:
# ---------------------------------------------------------------------------
# TileDBError                               Traceback (most recent call last)
# <ipython-input-46-7668590a214f> in <cell line: 16>()
#      14 schema = tiledb.ArraySchema(domain=dom, sparse=False, attrs=[rawdata])
#      15
# ---> 16 tiledb.Array.create(f"./CCF.tdb", schema = schema)
#      17
#      18 with tiledb.open(f"./CCF.tdb", 'w') as A:
#
# tiledb/libtiledb.pyx in tiledb.libtiledb.Array.create()
#
# tiledb/libtiledb.pyx in tiledb.libtiledb._raise_ctx_err()
#
# tiledb/libtiledb.pyx in tiledb.libtiledb._raise_tiledb_error()
#
# TileDBError: [TileDB::StorageManager] Error: Cannot create array; Array 'file:///content/CCF.tdb' already exists

# %%
# !du -h CCF.tdb
# Out:
# 8.0K	CCF.tdb/__schema
# 4.0K	CCF.tdb/__fragment_meta
# 4.0K	CCF.tdb/__commits
# 4.0K	CCF.tdb/__meta
# 319M	CCF.tdb/__fragments/__1714087557728_1714087557728_0b8ce5fc360a47d7b0c0dcc114ee0856_16
# 319M	CCF.tdb/__fragments/__1714087571012_1714087571012_eb5abc1ef4f64ba48996586437417098_16
# 637M	CCF.tdb/__fragments
# 637M	CCF.tdb

# %% [markdown]
# ### 5.3 TileDB.S3
# **There is the option to write TileDB directly to AWS S3 bucket.** So basically one can avoid writing local files (e.g., ASDF), but write from RAM to S3 directly. This is especially efficient when running xcorr jobs on AWS in a way that you don't need to have much local storage for the instance running sub-tasks (e.g., EBS).

# %%
# create a configuration object
config = tiledb.Config()

# set configuration parameters
config["vfs.s3.scheme"] = "https"
config["vfs.s3.region"] = "us-west-2"
config["vfs.s3.endpoint_override"] = ""
config["vfs.s3.use_virtual_addressing"] = "true"
config["vfs.s3.aws_access_key_id"] = "YOUR_AWS_ACCESS_KEY"
config["vfs.s3.aws_secret_access_key"] =  "YOUR_AWS_SECRET_ACCESS_KEY"

# create contex
ctx = tiledb.Ctx(config)

bucket = "s3://seisscoped-hps"

with tiledb.open(f"./CCF.tdb", 'w', ctx = ctx) as A:
    A[:, :] = corr_full

# %% [markdown]
# # EOF

# %%
def correlate(fft1_smoothed_abs,fft2,D,Nfft):
    import scipy
    #----load paramters----
    sps     = D['samp_freq']
    dt      = 1/sps
    maxlag  = D['maxlag']
    method  = D['cc_method']
    smoothspect_N = D['smoothspect_N']

    nwin  = fft2.shape[0]
    Nfft2 = fft2.shape[1]

    #------convert all 2D arrays into 1D to speed up--------
    corr = np.zeros(nwin*Nfft2,dtype=np.complex64)
    fft1 = np.repeat(fft1_smoothed_abs.reshape(1,fft1_smoothed_abs.size), nwin, axis = 0)  # duplicate fft1_smoothed_abs for nwin rows
    corr = fft1.reshape(fft1.size,)*fft2.reshape(fft2.size,)

    corr  = corr.reshape(nwin,Nfft2)

    # loop through each cross correlation
    ampmax = np.zeros(nwin,dtype=np.float32)

    crap   = np.zeros(shape=(nwin, Nfft), dtype=np.complex64)
    crap[:, :Nfft2] = corr
    crap[:, :Nfft2] -= np.mean(crap[:, :Nfft2], axis=-1, keepdims=True)
    crap[:, -(Nfft2)+1:] = np.flip(np.conj(crap[:, 1:(Nfft2)]), axis=-1)
    # crap[:, 0] = complex(0,0)
    s_corr = scipy.fftpack.ifftshift(scipy.fftpack.ifft(crap, Nfft, axis = -1), axes = -1).real

    # remove abnormal trace
    ampmax = np.max(s_corr,axis=1)
    tindx  = np.where( (ampmax<20*np.median(ampmax)) & (ampmax>0))[0]
    s_corr = s_corr[tindx,:]

    t = np.arange(-Nfft2,Nfft2)*dt
    ind = np.where(np.abs(t) <= maxlag)[0]
    if s_corr.ndim==1:
        s_corr = s_corr[ind]
    elif s_corr.ndim==2:
        s_corr = s_corr[:,ind]
    return s_corr,tindx

# %%
plt.figure(figsize = (12, 5), dpi = 100)

plt.imshow(corr_full[:, :(cha2 - cha1)].T, aspect = 'auto', cmap = 'RdBu',
           vmax = 2e-2, vmin = -2e-2, origin = 'lower', interpolation=None)

_ =plt.yticks(np.linspace(cha1, cha2, 4) - cha1,
              [int(i) for i in np.linspace(cha1, cha2, 4)], fontsize = 12)
_ = plt.xticks(np.arange(0, 801, 200), (np.arange(0, 801, 200) - 400)/50, fontsize = 12)
plt.ylabel("Channel number", fontsize = 16)
plt.xlabel("Time lag (sec)", fontsize = 16)
plt.title("source 500", fontsize = 16)
bar = plt.colorbar(pad = 0.1, format = lambda x, pos: '{:.1f}'.format(x*100))
bar.set_label('Cross-correlation Coefficient ($\\times10^{-2}$)', fontsize = 15)

twiny = plt.gca().twinx()
twiny.set_yticks(np.linspace(0, cha2 - cha1, 4),
                             [int(i* cha_spacing) for i in np.linspace(cha1, cha2, 4)])
twiny.set_ylabel("Distance along cable (m)", fontsize = 15)
# Out:
# Text(0, 0.5, 'Distance along cable (m)')

# %%
# I did change the both modes of normalizations to 'no'.
